# %%
#   enter a string say Indian Administrative Service
#   o/p should be IAS
#   hint use split, list to do this.
#   Note if the string is one word - Hello
#   then o/p should be Hello
str1=input("Enter a String :")
sp=str1.split(" ")
for i in range(0,len(sp)):
    if len(sp)==1:
        if str1.isalpha():
            s=str(str1)
            print(s)
    else:
        if str1[0].isalpha():
            p=sp[i][0]
            print(p.upper(),end="")
# Out:
# Enter a String :

# %%
#use dict for this , OOPS concept should be implemented
#   here
#   input roll,name,avg. roll is the Key and value
#   is name,avg and result - say as list
#   compute the result based on avg as following :
#   1-39 - Fail
#   40-49 - Pass
#   50-59 - Second class
#   60-74- First class
#   75-89 - distinction
#   90 and above - High Distinction
#   have methods like 
#   input_data()
#   process_avg()
#   display_all_details()
#   etc
#   Find out how many candidates secures more than class  avg.
#   display the student details who has highest and second highest
student={}
n=int(input("Enater a How Many Students : "))
for i in range(0,n+1):
    roll=int(input("Enter a ROLL_ID : "))
    name=input("Enter a Student NAME : ")
    avg=int(input("Enter a AVG  : " ))
    student.update({roll:[name,avg]})
print(student)

sName=[]
sAvg=[]

c=s=0
for k,v in student.items():
    
    sName.append(v[0])
    sAvg.append(v[1])
for i in sAvg:
    s=s+i
    c=c+1
    if 1<=i<=39:
        print("Fail")
    elif 40<=i<=49:
        print("pass")
    elif 50<=i<=59:
        print("Second Class")
    elif 60<=i<=74:
        print("First Class")
    elif 75<=i<=89:
        print("Distinction")
    elif 90<=i:
        print("High Distinction")
class_Avg=s//c
print(class_Avg)
m=max(sAvg)
sAvg.sort()
print(sAvg[-2])
# Out:
# Enater a How Many Students : 3
# Enter a ROLL_ID : 101
# Enter a Student NAME : arjun
# Enter a AVG  : 90
# Enter a ROLL_ID : 102
# Enter a Student NAME : kalus
# Enter a AVG  : 78
# Enter a ROLL_ID : 103
# Enter a Student NAME : doman
# Enter a AVG  : 56
# Enter a ROLL_ID : 104
# Enter a Student NAME : jaywanth
# Enter a AVG  : 34
# {101: ['arjun', 90], 102: ['kalus', 78], 103: ['doman', 56], 104: ['jaywanth', 34]}
# High Distinction
# Distinction
# Second Class
# Fail
# 64
# 78

# %%
#input the avg of the student
#   and the category say 
#   G - General
#   D - Defence
#   O - Others
#   also input the year of passing 
#   the criteria for admission is as follwing 
#   For G the avg must be above 80 and the 
#   YOP must be 2021
#   For D the avg must be above 68 and the YOP
#   can be 2019 2020 or 2021
#   For O then avg must not be less than 60 and 
#   YOP could be 2020 or 2021

#   if the candidate parents/gurdian income is 
#   less than 80000 pa and they have passed after 2019
#   and thier avg is above 55 then grant admission
#   otherwise no admission

avg=int(input("Enter a AVG : "))
categry=input("Enter a CATEGRY : ")
yop=int(input("Enter a YEAR OF PASSOUT : "))
income=int(input("Enter a INCOME : "))

if categry=='G':
    if avg>=80 and yop==2021:
        print("You qualifed for General")
    else:
        if income<=80000 and avg>=85 and yop==2019:
            print("You qualifed for General")
        else:
            print("NOT qualified General")
elif categry=='D':
    if ang>=68 and (yop==2019 or yop==2020 or yop==2021):
        print('You qualifed for Defence')
    else:
        if income<=80000 and avg>=85 and yop==2019:
            print("You qualifed for Defence")
        else:
            print("Not qualified for Deferec ")
elif categry=="O":
    if avg>=60 and (yop==2020 or yop==2021):
        print("You qualifed for Others")
    else:
        if income<=80000 and avg>=85 and yop==2019:
            print("you qualifed for Others")
        else:
            print("NOT qualified for Others")
# Out:
# Enter a AVG : 60
# Enter a CATEGRY : G
# Enter a YEAR OF PASSOUT : 2019
# Enter a INCOME : 80000
# NOT qualified General
