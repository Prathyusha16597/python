# %%
import random
n=int(input("Enter a how Many Numbers : "))
num=[]
sum=0
c1=0
c2=0
h=0
l=9999999
for i in range(1,n+1):
    n1=int(input("Enter a Number : "))
    num.append(i)
    i=i+1
    if 10<=n1<=99:
        if n1<h:
            n=h
        if n1>l:
            n=1
        c1=c1+1
for i in range(1,n+1): 
    if 100<=n1<=999:
        c2=c2+1
max(h)
min(l)
sum(n1)
avg=sum/100
print(h)
print(l)
print(c1)
print(c2)
print(h)
print(l)

# %%
2# generate 100 random numbers between 1 to 1000
#   store them in the list
#   find the sum, avg, max,min
#   How many numbers are 3 digits
#   How many are 2 digits number
#   which is the highest 2 digit number and lowest 2 digit numbers
import random
sum=0
c1=0
c2=0
h=0
l=9999
l1 = []

for i in range(0,100):  
    n = random.randint(1,1000)  
    l1.append(n)
for i in l1:
    if 100<=i<=999:
        c1=c1+1
for j in l1:
    if 10<=j<=99:
        c2=c2+1
        if(j>h):
            h=j
        if(j<l):
            l=j
for h in range(0,len(l1)):
    sum=sum+l1[h]
avg=sum/100
print("print Random Numbers : ",l1)
print("Max of Randam Number : ",max(l1))
print("Min of Randam Number : ",min(l1))
print("How many numbers are 3 digits : ",c1)
print("How many numbers are 2 digits : ",c2)
print("which is the highest 2 digit : ",h)
print("which is the lowest 2 digit : ",l)
print("Sum of the Randam Numbers : ",sum)
print("Avg of the Randam Numbers : ",avg)
# Out:
# print Random Numbers :  [709, 651, 35, 293, 892, 319, 621, 322, 972, 773, 416, 28, 740, 117, 548, 509, 290, 943, 975, 162, 96, 664, 702, 9, 551, 27, 261, 916, 247, 732, 306, 96, 790, 486, 678, 923, 290, 433, 152, 416, 555, 919, 532, 23, 255, 465, 726, 789, 338, 930, 412, 19, 498, 550, 749, 648, 148, 562, 708, 387, 96, 803, 829, 949, 572, 213, 814, 819, 700, 740, 255, 198, 682, 949, 841, 760, 90, 215, 352, 588, 246, 566, 681, 279, 455, 689, 122, 159, 283, 879, 834, 963, 524, 554, 913, 244, 986, 206, 771, 799]
# Max of Randam Number :  986
# Min of Randam Number :  9
# How many numbers are 3 digits :  90
# How many numbers are 2 digits :  9
# which is the highest 2 digit :  99
# which is the lowest 2 digit :  19
# Sum of the Randam Numbers :  51921
# Avg of the Randam Numbers :  519.21

# %%
#use if else....and or etc...
#use user defined functions for this...dono just write everything in one BLOCK

#1) Given the electricity bill rates 
#  input the initial meter reading
#  input the final meter reading
#  input the category
#  final - initial is the unit consumed, based on that calculate the 
#  bill. ONLY In domestic catg if the residence has Solar installation then
#  give 10% discount on the bill which is above 2000/-

#  for Domestic catg
#     0 to 1000    1.75 per unit 
#   1001 to 2500	  2.50 per unit 
#   2501 to 4500   3.70 per unit 
#   4501 onwards   5.25 per unit

# for Commercial catg
#     0 to 2200    2.75 per unit 
#   2201 to 4500	  3.75 per unit 
#   4501 to 7000   4.90 per unit 
#   7001 onwards   6.40 per unit
#   add 15.5% GST for the bill generated.
#   in commercial catg if the unit consumed is above 8000 then put a fine amount of
#   5% on the bill amount after computing the GST.

i=float(input("Initial meter reading : "))
f=float(input("Final meter reading : "))
c=input("Enter the  category : ")
r=input("Solar installation")
u=f-i
a=0
b=0
d=0
fine=0
if c=="Domestic":
    if 0<=u<=100:
        a=u*1.75
    if 1001<=u<=2500:
        a=u*2.50
    if  2501<=u<=4500:
        a=u*3.70
    if u>4501:
        a=u*5.25
    if r=="yes":
        if a>=2000:
            d=a-(a*0.1)
elif c=="commercial":
    if 0<=u<=2200:
        b=u*2.75
    if 2201<=u<=4500:
        b=u*3.75
    if 4501<=u<=7000:
        b=u*4.90
    if u>7001:
        b=u*6.40
g1=a+(a*0.155)
g2=b+(b*0.155)
if u>=8000 and c=="commercial":
    fine=g2+(g2*0.005)
print("unit : ",u)
print("Total Amount of Domestic bill : ",a)
print("Soloar installation  10%  discount on the bill : ",d)
print("With gst domestic bill is:",g1)
print("Total amount of commerical bill is:",b)
print("With gst commerical bill is:",g2)
print("Fine for commerical if unit is more than 8000 unit:",fine)
# Out:
# Initial meter reading : 8000
# Final meter reading : 2345
# Enter the  category : 3452
# Solar installationyes
# unit :  -5655.0
# Total Amount of Domestic bill :  0
# Soloar installation  10%  discount on the bill :  0
# With gst domestic bill is: 0.0
# Total amount of commerical bill is: 0
# With gst commerical bill is: 0.0
# Fine for commerical if unit is more than 8000 unit: 0

# %%
total_bill=0
y=0
bill,bill1,bill2,bill3,bill4=0,0,0,0,0
v=set()

while True:
    while True:
        itemno=int(input("enter the item.no:"))
        quant=float(input("enter the quantatity:"))
        if(itemno==0 and quant==0):
            break
        if(itemno==1):
            price=15 
            bill=quant*price
            print("coffe/tea per cup price is:",price)
        if(itemno==2):
            price1=30
            bill1=quant*price1
            print("Snacks type I per plate price is:",price1)
        if(itemno==3):
            price2=42
            bill2=quant*price2
            print("Snacks type II per plate price is:",price2)
        if(itemno==4):
            price3=85
            bill3=quant*price3
            print("Executive Meals per plate price is:",price3)
        if(itemno==5):
            price4=120
            bill4=quant*price4
            print("Spl Meals per plate price is:",price4)
            
        
    ph_no=input("enter the ph_number:")
    if(len(ph_no)==10):
        print("enter ph_no is valid")
    else:
        print("enter ph_no is invalid")
    cat=input("enter the category:")
    total_bill=(bill+bill1+bill2+bill3+bill4)
    if(cat=="d"):
        y=total_bill-(total_bill*0.10)
        print("10 percentage discount on the bill as he/she is defence person:",y)
    elif(cat=="s"):
        y=total_bill-(total_bill*0.04)
        print("4 percentage discount on bill as he/she is Senior Citizen:",y)
    elif(cat=="regular"):
        y=total_bill
        print("he/she is regular customer",y)
    print(ph_no)
    print("itemno1 bill:",bill) 
    print("itemno2 bill:",bill1)
    print("itemno3 bill:",bill2)
    print("itemno4 bill:",bill3)
    print("itemno5 bill:",bill4)
    print("Total bill amount:",total_bill)
    u=(ph_no,y,cat)
    print(u)   
    v.add(u)
    print(v)

    print("mobile_number        bill          category" )
    for j in v:
	    print(j[0], "         " ,j[1],"    ", j[2])
    
    c=input("enter exit to quit:")
    if(c=='exit'):
        break
# Out:
# enter the item.no:4
# enter the quantatity:1.5
# Executive Meals per plate price is: 85
# enter the item.no:3
# enter the quantatity:2
# Snacks type II per plate price is: 42
# enter the item.no:2
# enter the quantatity:3
# Snacks type I per plate price is: 30
# enter the item.no:6
# enter the quantatity:4
# enter the item.no:0
# enter the quantatity:0
# enter the ph_number:7877372390
# enter ph_no is valid
# enter the category:s
# 4 percentage discount on bill as he/she is Senior Citizen: 289.44
# 7877372390
# itemno1 bill: 0
# itemno2 bill: 90.0
# itemno3 bill: 84.0
# itemno4 bill: 127.5
# itemno5 bill: 0
# Total bill amount: 301.5
# ('7877372390', 289.44, 's')
# {('7877372390', 289.44, 's')}
# mobile_number        bill          category
# 7877372390           289.44      s
# enter exit to quit:c
# enter the item.no:2
# enter the quantatity:5
# Snacks type I per plate price is: 30
# enter the item.no:0
# enter the quantatity:1
# enter the item.no:0
# enter the quantatity:0
# ...
